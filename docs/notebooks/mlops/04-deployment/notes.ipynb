# %% [markdown]
# # Model Deployment

# %% [markdown]
# deployment
#
# batch (offline)
# - run regularly
#
# online
# - up running all the time
#  - web service (http requests, get back prediction)
#  - streaming (stream of events, model services listening for events on the stream and react to this)

# %% [markdown]
# ⚠️ **Attribution:** These are notes for [Module 4: Model Deployment](https://github.com/DataTalksClub/mlops-zoomcamp/blob/main/04-deployment) of the [MLOps Zoomcamp](https://github.com/DataTalksClub/mlops-zoomcamp). The MLOps Zoomcamp is a free course from [DataTalks.Club](https://github.com/DataTalksClub).

# %% [markdown]
# batch mode
# - regularly (every day, hourly, monthly, etc)
# - database of all data (pull data from db -> apply model)
# - scoring job
# - daily: get all data from yesterday
# - hourly: get all data from previous hour
# - and so on
# - write to predictions db
# - something can read from predictions db and react on this predictions, e.g. report
# - marketing related tasks, e.g. churn prediction
# - no need to know that user is about to churn immediately
# - (i.e. churning does not occur at a small time interval)
#
# web service
# - contains model
# - ride duration prediction
# - backend sends info to service (pu location id, dropoff, time of day, etc)
# - send back prediction, then passed to user
# - needs to be up all the time.
# - user uses app, checks ride duration, and decides whether to hire taxi or not.
# - for this decision we can't wait five minutes, need this immediately.
#
# streaming
# - producer and consumers
# - producer pushes event to event stream and consumers wil read from this stream.
# - and react to these events.
# - recall web service: 1-1 relationship (explicit connection between user and service)
# - 1-many  / many - many.
# - user -> producer=backend -> send event containing all info about ride ->
#      services will react on this event
#
# - e.g. one consuming service predict tip -> send push notif to user asking for tip.
# - duration prediction (web service) = okay pred
# - streaming service, better ride duration prediction -> update prediction.
# - only implicit connection, we dont know which consumer will react, how many
# - example: content moderation
#     - user -> video -> event -> C1 (copyright)
#                              -> C2 (NSFW)        -> prediction stream -> decision service
#                              -> C2 (violence)
#
# - can be scaled to infinitely many services or models (in principle)

# %% [markdown]
# ## Deploying a model as a web service

# %% [markdown]
# ```
# app
# data
# ride_duration
# |- VERSION
# |- __init__.py
# Dockerfile
# setup.py
# project.toml
# MANIFEST.in
# ```

# %% [markdown]
# ```bash
# pipenv install scikit-learn==1.0.2 flask pandas mlflow --python=3.9
# pipenv install
# pipenv install --dev requests
# pipenv install --dev pipenv-setup
# pipenv-setup sync
# ```

# %%
edit pipfile -> pipenv install

# %%
import requests
import json

ride = [{
    'VendorID': 2,
    'store_and_fwd_flag': 'N',
    'RatecodeID': 1.0,
    'PULocationID': 130,
    'DOLocationID': 205,
    'passenger_count': 5.0,
    'trip_distance': 3.66,
    'fare_amount': 14.0,
    'extra': 0.5,
    'mta_tax': 0.5,
    'tip_amount': 10.0,
    'tolls_amount': 0.0,
    'ehail_fee': None,
    'improvement_surcharge': 0.3,
    'total_amount': 25.3,
    'payment_type': 1.0,
    'trip_type': 1.0,
    'congestion_surcharge': 0.0
}]


host = 'http://192.168.254.180:9696'
url = f'{host}/predict'
response = requests.post(url, json=ride)
result = response.json()
print(json.dumps(result, indent=4))
# Out:
# {
#     "duration": 12.265893072879651
# }

# %% [markdown]
# ```bash
# ```

# %%
get model from mlflow registry using run id
problematic if server goes down
we become dependent on tracking server.
-> go directly to artifact root.

# %% [markdown]
# ## Batch deployment

# %% [markdown]
# We want to look at how often drivers deviate from the predicted duration. Can be useful for analytics.

# %%
import requests
import json

ride = [{
    'PULocationID': 130,
    'DOLocationID': 205,
    'trip_distance': 3.66,
}]


host = 'http://0.0.0.0:9696'
url = f'{host}/predict'
response = requests.post(url, json=ride)
result = response.json()

print(json.dumps(result, indent=4))
# Out:
# {
#     "duration": 12.265893072879651
# }

# %%
import pandas as pd

df = pd.read_parquet('data/green_tripdata_2021-01.parquet')
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0             5.50   0.50      0.5        0.00          0.00      None
# 1            10.00   0.50      0.5        2.81          0.00      None
# 2             6.00   0.50      0.5        1.00          0.00      None
# 3             8.00   0.50      0.5        0.00          0.00      None
# 4           -52.00   0.00     -0.5        0.00          0.00      None
# ...            ...    ...      ...         ...           ...       ...
# 76513        56.23   2.75      0.0        0.00          6.12      None
# 76514        46.66   0.00      0.0       12.20          6.12      None
# 76515        18.95   2.75      0.0        0.00          0.00      None
# 76516        48.87   2.75      0.0        0.00          6.12      None
# 76517        15.45   2.75      0.0        0.00          0.00      None
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         65.40           NaN        NaN
# 76514                    0.3         65.28           NaN        NaN
# 76515                    0.3         22.00           NaN        NaN
# 76516                    0.3         58.04           NaN        NaN
# 76517                    0.3         18.50           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      2.75
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 76513                   NaN
# 76514                   NaN
# 76515                   NaN
# 76516                   NaN
# 76517                   NaN
#
# [76518 rows x 20 columns]

# %%
from ride_model.predict import load_model
from ride_model.predict import make_prediction

model = load_model()
make_prediction(model, df)
# Out:
# array([ 4.40383416,  8.83057186,  6.81991632, ..., 17.4479256 ,
#        33.38209552, 13.17360371])

# %%
pd.read_parquet('output/green/2021-01.parquet')
# Out:
#                                     ride_id lpep_pickup_datetime  \
# 0      d685e8a5-3374-453d-acb2-20fb17445dad  2021-01-01 00:15:56
# 1      488137c5-c8f9-44aa-9995-884d16800d0a  2021-01-01 00:25:59
# 2      c8a71eb8-dc60-4223-b81c-520d1e4726f6  2021-01-01 00:45:57
# 3      572f288d-f6d7-44e2-bca0-a17e0f920914  2020-12-31 23:57:51
# 4      15c5da8f-13fa-4047-8566-8c25865943ee  2021-01-01 00:26:31
# ...                                     ...                  ...
# 73903  23134189-8855-476f-8f66-ab3d6f93ee0c  2021-01-31 21:38:00
# 73904  11b8fc14-744b-4d74-9048-39a2651dd7c9  2021-01-31 22:43:00
# 73905  494fc2dc-8b72-49f1-99df-7243c0bf0506  2021-01-31 22:16:00
# 73906  4b5220e3-005f-41ac-b4a3-503806f5e127  2021-01-31 23:10:00
# 73907  c81c3b92-29b0-4823-a8c6-b93bcbf69faf  2021-01-31 23:25:00
#
#        PULocationID  DOLocationID  actual_duration  predicted_duration  \
# 0                43           151         3.933333            4.403834
# 1               166           239         8.750000            8.830572
# 2                41            42         5.966667            6.819916
# 3               168            75         7.083333           13.923927
# 4                75            75         2.316667            6.735151
# ...             ...           ...              ...                 ...
# 73903            81            90        38.000000           40.089000
# 73904            35           213        38.000000           31.554369
# 73905            74            69        11.000000           17.447926
# 73906           168           215        27.000000           33.382096
# 73907           119           244        10.000000           13.173604
#
#            diff                     model_version
# 0     -0.470501  e1efc53e9bd149078b0c12aeaa6365df
# 1     -0.080572  e1efc53e9bd149078b0c12aeaa6365df
# 2     -0.853250  e1efc53e9bd149078b0c12aeaa6365df
# 3     -6.840594  e1efc53e9bd149078b0c12aeaa6365df
# 4     -4.418484  e1efc53e9bd149078b0c12aeaa6365df
# ...         ...                               ...
# 73903 -2.089000  e1efc53e9bd149078b0c12aeaa6365df
# 73904  6.445631  e1efc53e9bd149078b0c12aeaa6365df
# 73905 -6.447926  e1efc53e9bd149078b0c12aeaa6365df
# 73906 -6.382096  e1efc53e9bd149078b0c12aeaa6365df
# 73907 -3.173604  e1efc53e9bd149078b0c12aeaa6365df
#
# [73908 rows x 8 columns]

# %%
from ride_duration.utils import load_training_dataframe, prepare_features

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import make_pipeline


def train_pipeline(params, X_train, y_train, X_valid, y_valid):
    """Fit and save preprocessing pipeline."""

    with mlflow.start_run(nested=True):
        
        pipe = make_pipeline(
            DictVectorizer(),
            RandomForestRegressor(**params)
        )
        
        pipe.fit(X_train, y_train)

        # MLflow logging
        y_pred_train = pipe.predict(X_train)
        y_pred_valid = pipe.predict(X_valid)

        rmse_train = mean_squared_error(y_train, y_pred_train, squared=False)
        rmse_valid = mean_squared_error(y_valid, y_pred_valid, squared=False)

        mlflow.log_metric('rmse_train', rmse_train)
        mlflow.log_metric('rmse_valid', rmse_valid)
        mlflow.sklearn.log_model(pipe, artifact_path='models')


TRACKING_SERVER_HOST = "ec2-34-229-91-27.compute-1.amazonaws.com"
TRACKING_URI = f"http://{TRACKING_SERVER_HOST}:5000"
mlflow.set_tracking_uri(TRACKING_URI)
mlflow.set_experiment("nyc-taxi-experiment")

train_path = './data/green_tripdata_2021-01.parquet'
valid_path = './data/green_tripdata_2021-02.parquet'

train_data = load_training_dataframe(train_path)
valid_data = load_training_dataframe(valid_path)

X_train = train_data.drop(['duration'], axis=1)
X_valid = valid_data.drop(['duration'], axis=1)
y_train = train_data.duration.values
y_valid = valid_data.duration.values


for n_estimators in [300]:
    for max_depth in [2, 8]:
        params = {
            'n_estimators': n_estimators,
            'max_depth': max_depth,
        }

        train_pipeline(
            params,
            prepare_features(X_train), y_train,
            prepare_features(X_valid), y_valid,
        )
# Out:
# 2022/06/17 01:44:46 WARNING mlflow.sklearn: Failed to infer model signature: Expected one of (pandas.DataFrame, numpy array, dictionary of (name -> numpy.ndarray), pyspark.sql.DataFrame) but got '<class 'list'>'
# 2022/06/17 01:44:49 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: Parameter validation failed:
# Invalid bucket name "": Bucket name must match the regex "^[a-zA-Z0-9.\-_]{1,255}$" or be an ARN matching the regex "^arn:(aws).*:(s3|s3-object-lambda):[a-z\-0-9]*:[0-9]{12}:accesspoint[/:][a-zA-Z0-9\-.]{1,63}$|^arn:(aws).*:s3-outposts:[a-z\-0-9]+:[0-9]{12}:outpost[/:][a-zA-Z0-9\-]{1,63}[/:]accesspoint[/:][a-zA-Z0-9\-]{1,63}$"
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# /Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb Cell 20' in <cell line: 50>()
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=50'>51</a> for max_depth in [2, 8]:
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=51'>52</a>     params = {
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=52'>53</a>         'n_estimators': n_estimators,
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=53'>54</a>         'max_depth': max_depth,
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=54'>55</a>     }
# ---> <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=56'>57</a>     train_pipeline(
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=57'>58</a>         params,
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=58'>59</a>         prepare_features(X_train), y_train,
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=59'>60</a>         prepare_features(X_valid), y_valid,
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=60'>61</a>     )
#
# /Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb Cell 20' in train_pipeline(params, X_train, y_train, X_valid, y_valid)
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=27'>28</a> mlflow.log_metric('rmse_train', rmse_train)
#      <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=28'>29</a> mlflow.log_metric('rmse_valid', rmse_valid)
# ---> <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000025?line=29'>30</a> mlflow.sklearn.log_model(pipe, artifact_path='models')
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/sklearn/__init__.py:393, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements)
#     309 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     310 def log_model(
#     311     sk_model,
#    (...)
#     321     extra_pip_requirements=None,
#     322 ):
#     323     """
#     324     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     325     containing the following flavors:
#    (...)
#     391         mlflow.sklearn.log_model(sk_model, "sk_models")
#     392     """
# --> 393     return Model.log(
#     394         artifact_path=artifact_path,
#     395         flavor=mlflow.sklearn,
#     396         sk_model=sk_model,
#     397         conda_env=conda_env,
#     398         code_paths=code_paths,
#     399         serialization_format=serialization_format,
#     400         registered_model_name=registered_model_name,
#     401         signature=signature,
#     402         input_example=input_example,
#     403         await_registration_for=await_registration_for,
#     404         pip_requirements=pip_requirements,
#     405         extra_pip_requirements=extra_pip_requirements,
#     406     )
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/models/model.py:295, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, **kwargs)
#     293 mlflow_model = cls(artifact_path=artifact_path, run_id=run_id)
#     294 flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# --> 295 mlflow.tracking.fluent.log_artifacts(local_path, artifact_path)
#     296 try:
#     297     mlflow.tracking.fluent._record_logged_model(mlflow_model)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/tracking/fluent.py:726, in log_artifacts(local_dir, artifact_path)
#     697 """
#     698 Log all the contents of a local directory as artifacts of the run. If no run is active,
#     699 this method will create a new active run.
#    (...)
#     723         mlflow.log_artifacts("data", artifact_path="states")
#     724 """
#     725 run_id = _get_or_start_run().info.run_id
# --> 726 MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/tracking/client.py:1001, in MlflowClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     957 def log_artifacts(
#     958     self, run_id: str, local_dir: str, artifact_path: Optional[str] = None
#     959 ) -> None:
#     960     """
#     961     Write a directory of files to the remote ``artifact_uri``.
#     962
#    (...)
#     999         is_dir: True
#    1000     """
# -> 1001     self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:346, in TrackingServiceClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     339 def log_artifacts(self, run_id, local_dir, artifact_path=None):
#     340     """
#     341     Write a directory of files to the remote ``artifact_uri``.
#     342
#     343     :param local_dir: Path to the directory of files to write.
#     344     :param artifact_path: If provided, the directory in ``artifact_uri`` to write to.
#     345     """
# --> 346     self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/store/artifact/s3_artifact_repo.py:141, in S3ArtifactRepository.log_artifacts(self, local_dir, artifact_path)
#     139     upload_path = posixpath.join(dest_path, rel_path)
#     140 for f in filenames:
# --> 141     self._upload_file(
#     142         s3_client=s3_client,
#     143         local_file=os.path.join(root, f),
#     144         bucket=bucket,
#     145         key=posixpath.join(upload_path, f),
#     146     )
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/store/artifact/s3_artifact_repo.py:117, in S3ArtifactRepository._upload_file(self, s3_client, local_file, bucket, key)
#     115 if environ_extra_args is not None:
#     116     extra_args.update(environ_extra_args)
# --> 117 s3_client.upload_file(Filename=local_file, Bucket=bucket, Key=key, ExtraArgs=extra_args)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/boto3/s3/inject.py:143, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     108 """Upload a file to an S3 object.
#     109
#     110 Usage::
#    (...)
#     140     transfer.
#     141 """
#     142 with S3Transfer(self, Config) as transfer:
# --> 143     return transfer.upload_file(
#     144         filename=Filename,
#     145         bucket=Bucket,
#     146         key=Key,
#     147         extra_args=ExtraArgs,
#     148         callback=Callback,
#     149     )
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/boto3/s3/transfer.py:288, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     284 future = self._manager.upload(
#     285     filename, bucket, key, extra_args, subscribers
#     286 )
#     287 try:
# --> 288     future.result()
#     289 # If a client error was raised, add the backwards compatibility layer
#     290 # that raises a S3UploadFailedError. These specific errors were only
#     291 # ever thrown for upload_parts but now can be thrown for any related
#     292 # client error.
#     293 except ClientError as e:
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/s3transfer/futures.py:103, in TransferFuture.result(self)
#      98 def result(self):
#      99     try:
#     100         # Usually the result() method blocks until the transfer is done,
#     101         # however if a KeyboardInterrupt is raised we want want to exit
#     102         # out of this and propagate the exception.
# --> 103         return self._coordinator.result()
#     104     except KeyboardInterrupt as e:
#     105         self.cancel()
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/s3transfer/futures.py:266, in TransferCoordinator.result(self)
#     263 # Once done waiting, raise an exception if present or return the
#     264 # final result.
#     265 if self._exception:
# --> 266     raise self._exception
#     267 return self._result
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/s3transfer/tasks.py:139, in Task.__call__(self)
#     135     # If the task is not done (really only if some other related
#     136     # task to the TransferFuture had failed) then execute the task's
#     137     # main() method.
#     138     if not self._transfer_coordinator.done():
# --> 139         return self._execute_main(kwargs)
#     140 except Exception as e:
#     141     self._log_and_set_exception(e)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/s3transfer/tasks.py:162, in Task._execute_main(self, kwargs)
#     159 # Log what is about to be executed.
#     160 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 162 return_value = self._main(**kwargs)
#     163 # If the task is the final task, then set the TransferFuture's
#     164 # value to the return value from main().
#     165 if self._is_final:
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/s3transfer/upload.py:758, in PutObjectTask._main(self, client, fileobj, bucket, key, extra_args)
#     749 """
#     750 :param client: The client to use when calling PutObject
#     751 :param fileobj: The file to upload.
#    (...)
#     755     used in the upload.
#     756 """
#     757 with fileobj as body:
# --> 758     client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/botocore/client.py:508, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     504     raise TypeError(
#     505         f"{py_operation_name}() only accepts keyword arguments."
#     506     )
#     507 # The "self" in this scope is referring to the BaseClient.
# --> 508 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/botocore/client.py:878, in BaseClient._make_api_call(self, operation_name, api_params)
#     869     logger.debug(
#     870         'Warning: %s.%s() is deprecated', service_name, operation_name
#     871     )
#     872 request_context = {
#     873     'client_region': self.meta.region_name,
#     874     'client_config': self.meta.config,
#     875     'has_streaming_input': operation_model.has_streaming_input,
#     876     'auth_type': operation_model.auth_type,
#     877 }
# --> 878 request_dict = self._convert_to_request_dict(
#     879     api_params, operation_model, context=request_context
#     880 )
#     881 resolve_checksum_context(request_dict, operation_model, api_params)
#     883 service_id = self._service_model.service_id.hyphenize()
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/botocore/client.py:936, in BaseClient._convert_to_request_dict(self, api_params, operation_model, context)
#     933 def _convert_to_request_dict(
#     934     self, api_params, operation_model, context=None
#     935 ):
# --> 936     api_params = self._emit_api_params(
#     937         api_params, operation_model, context
#     938     )
#     939     request_dict = self._serializer.serialize_to_request(
#     940         api_params, operation_model
#     941     )
#     942     if not self._client_config.inject_host_prefix:
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/botocore/client.py:969, in BaseClient._emit_api_params(self, api_params, operation_model, context)
#     961 responses = self.meta.events.emit(
#     962     f'provide-client-params.{service_id}.{operation_name}',
#     963     params=api_params,
#     964     model=operation_model,
#     965     context=context,
#     966 )
#     967 api_params = first_non_none_response(responses, default=api_params)
# --> 969 self.meta.events.emit(
#     970     f'before-parameter-build.{service_id}.{operation_name}',
#     971     params=api_params,
#     972     model=operation_model,
#     973     context=context,
#     974 )
#     975 return api_params
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)
#     254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/botocore/handlers.py:276, in validate_bucket_name(params, **kwargs)
#     270 if not VALID_BUCKET.search(bucket) and not VALID_S3_ARN.search(bucket):
#     271     error_msg = (
#     272         f'Invalid bucket name "{bucket}": Bucket name must match '
#     273         f'the regex "{VALID_BUCKET.pattern}" or be an ARN matching '
#     274         f'the regex "{VALID_S3_ARN.pattern}"'
#     275     )
# --> 276     raise ParamValidationError(report=error_msg)
#
# ParamValidationError: Parameter validation failed:
# Invalid bucket name "": Bucket name must match the regex "^[a-zA-Z0-9.\-_]{1,255}$" or be an ARN matching the regex "^arn:(aws).*:(s3|s3-object-lambda):[a-z\-0-9]*:[0-9]{12}:accesspoint[/:][a-zA-Z0-9\-.]{1,63}$|^arn:(aws).*:s3-outposts:[a-z\-0-9]+:[0-9]{12}:outpost[/:][a-zA-Z0-9\-]{1,63}[/:]accesspoint[/:][a-zA-Z0-9\-]{1,63}$"

# %%
# !aws s3 ls
# Out:
# 2022-06-17 00:01:19 mlflow-models-ron

# %%
mlflow.get_artifact_uri()
# Out:
# 's3:1/54285958c9f244e0af8615ee2caf09ea/artifacts'

# %%
client = MlflowClient(tracking_uri=TRACKING_URI)
print(client.list_experiments())

# %%
import mlflow
from mlflow.tracking import MlflowClient
# Out:
# [<Experiment: artifact_location='s3://mlflow-models-ron/0', experiment_id='0', lifecycle_stage='active', name='Default', tags={}>]

# %%
logged_model = f's3://mlflow-models-ron/0/{1}/artifacts/model'
model = mlflow.pyfunc.load_model(logged_model)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# /Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb Cell 18' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000017?line=0'>1</a> logged_model = f's3://mlflow-models-ron/0/{1}/artifacts/model'
# ----> <a href='vscode-notebook-cell:/Users/particle1331/code/inefficient-networks/docs/notebooks/mlops/04-deployment/notes.ipynb#ch0000017?line=1'>2</a> model = mlflow.pyfunc.load_model(logged_model)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/pyfunc/__init__.py:716, in load_model(model_uri, suppress_warnings, dst_path)
#     690 def load_model(
#     691     model_uri: str, suppress_warnings: bool = False, dst_path: str = None
#     692 ) -> PyFuncModel:
#     693     """
#     694     Load a model stored in Python function format.
#     695
#    (...)
#     714                      path will be created.
#     715     """
# --> 716     local_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     718     if not suppress_warnings:
#     719         _warn_dependency_requirement_mismatches(local_path)
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/tracking/artifact_utils.py:94, in _download_artifact_from_uri(artifact_uri, output_path)
#      91     parsed_uri = parsed_uri._replace(path=posixpath.dirname(parsed_uri.path))
#      92     root_uri = prefix + urllib.parse.urlunparse(parsed_uri)
# ---> 94 return get_artifact_repository(artifact_uri=root_uri).download_artifacts(
#      95     artifact_path=artifact_path, dst_path=output_path
#      96 )
#
# File ~/miniforge3/envs/deployment/lib/python3.9/site-packages/mlflow/store/artifact/artifact_repo.py:265, in ArtifactRepository.download_artifacts(self, artifact_path, dst_path)
#     262         failed_downloads[inflight_download.src_artifact_path] = repr(e)
#     264 if len(failed_downloads) > 0:
# --> 265     raise MlflowException(
#     266         message=(
#     267             "The following failures occurred while downloading one or more"
#     268             " artifacts from {artifact_root}: {failures}".format(
#     269                 artifact_root=self.artifact_uri,
#     270                 failures=failed_downloads,
#     271             )
#     272         )
#     273     )
#     274 return dst_local_path
#
# MlflowException: The following failures occurred while downloading one or more artifacts from s3://mlflow-models-ron/0/1/artifacts: {'model': "ClientError('An error occurred (404) when calling the HeadObject operation: Not Found')"}
