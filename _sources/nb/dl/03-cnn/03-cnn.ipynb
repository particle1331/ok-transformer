# %% [markdown]
# (dl/03-cnn)=
# # Convolutional Neural Networks

# %%
# !rm chapter.py; touch chapter.py

# %% [markdown]
# Feed-forward neural networks are general and versatile.
# But its unconstrained nature make a purely feed-forward network difficult to train and generalize, especially for datasets
# with prior structure. In particular, we consider data
# that can be represented as a grid structure such that nearby elements have strong local dependency. Common
# examples are images, sound, or similar sequential data with spatial orientation as key attribute.
#
# In this chapter, we introduce the **convolution operation**, which can be thought of as a filter that is applied spatially in a homogenous manner. Stacking convolutional layers allow the network to learn hierarchical patterns that generalize well to test data.
# We will apply this architecture to image and text classification.

# %% [markdown]
# ```{figure} https://www.d2l.ai/_images/lenet.svg
# ---
# align: center
# ---
# LeNet-5 (1989). [Source](https://www.d2l.ai/chapter_convolutional-neural-networks/lenet.html)
# ```

# %% [markdown]
# ## References
#
# - {cite}`raschka2022`
# - [CS231n: Convolutional Neural Networks for Visual Recognition](https://cs231n.github.io/convolutional-networks/)
# - [Convolutional Neural Networks for Text](https://lena-voita.github.io/nlp_course/models/convolutional.html)
# - [Keras Guides: Transfer learning & fine-tuning](https://keras.io/guides/transfer_learning/#finetuning)
